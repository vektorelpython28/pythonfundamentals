# %% [markdown]
# # Exception Handling
# * try -- except
# * exception hiearchy
# * finally
# * raise

# %% [markdown]
# ## try -- except

# %%
a = int(input("1. Sayıyı Giriniz:"))
b = int(input("2. Sayıyı Giriniz:"))
print(a/b)
print("Program Çalışmaya Devam Ediyor")
# Out:
# 1. Sayıyı Giriniz:a
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-452206372ff3> in <module>
# ----> 1 a = int(input("1. Sayıyı Giriniz:"))
#       2 b = int(input("2. Sayıyı Giriniz:"))
#       3 print(a/b)
#       4 print("Program Çalışmaya Devam Ediyor")
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
try:
    a = int(input("1. Sayıyı Giriniz:"))
    b = int(input("2. Sayıyı Giriniz:"))
    print(a/b)
except:
    print("Hata Verdi")
print("Program Çalışmaya Devam Ediyor")
# Out:
# 1. Sayıyı Giriniz:w
# Hata Verdi
# Program Çalışmaya Devam Ediyor

# %%
try:
    a = int(input("1. Sayıyı Giriniz:"))
    b = int(input("2. Sayıyı Giriniz:"))
    print(a/b)
except Exception as hata:
    print("Hata Verdi  =>",hata)
print("Program Çalışmaya Devam Ediyor")
# Out:
# 1. Sayıyı Giriniz:5
# 2. Sayıyı Giriniz:0
# Hata Verdi  => division by zero
# Program Çalışmaya Devam Ediyor

# %%
try:
    a = int(input("1. Sayıyı Giriniz:"))
    b = int(input("2. Sayıyı Giriniz:"))
    print(a/b)
except ValueError:
    print("Değer Hatası")
except ZeroDivisionError:
    print("Sıfıra Bölme Hatası")
print("Program Çalışmaya Devam Ediyor")
# Out:
# 1. Sayıyı Giriniz:5
# 2. Sayıyı Giriniz:0
# Sıfıra Bölme Hatası
# Program Çalışmaya Devam Ediyor

# %%
try:
    a = int(input("1. Sayıyı Giriniz:"))
    b = int(input("2. Sayıyı Giriniz:"))
    print(a/b)
except ValueError:
    print("Değer Hatası")
except Exception:
    print("Genel Hata")
print("Program Çalışmaya Devam Ediyor")
# Out:
# 1. Sayıyı Giriniz:5
# 2. Sayıyı Giriniz:0
# Genel Hata
# Program Çalışmaya Devam Ediyor

# %% [markdown]
# ### Exception Hierarchy
# https://docs.python.org/3/library/exceptions.html

# %%
try:
    a = int(input("1. Sayıyı Giriniz:"))
    b = int(input("2. Sayıyı Giriniz:"))
    print(a/b)
except Exception:
    print("Genel Hata")
except ValueError:
    print("Değer Hatası")

print("Program Çalışmaya Devam Ediyor")
# Out:
# 1. Sayıyı Giriniz:a
# Genel Hata
# Program Çalışmaya Devam Ediyor

# %%
try:
    a = int(input("1. Sayıyı Giriniz:"))
    b = int(input("2. Sayıyı Giriniz:"))
except ValueError:
    print("Değer Hatası")
else:
    try:
        print(a/b)
    except ZeroDivisionError:
        print("Sıfıra Bölme Hatası")
print("Program Çalışmaya Devam Ediyor")
# Out:
# 1. Sayıyı Giriniz:5
# 2. Sayıyı Giriniz:2
# 2.5
# Program Çalışmaya Devam Ediyor

# %% [markdown]
# https://vektorelpyt-pythonfunda-n2gvt65sk16.ws-eu78.gitpod.io/

# %% [markdown]
# ## finally

# %%
try:
    a = int(input("1. Sayıyı Giriniz:"))
    b = int(input("2. Sayıyı Giriniz:"))
    print(a/b)
except ValueError:
    print("Değer Hatası")
except ZeroDivisionError:
    print("Sıfıra Bölme Hatası")
finally:
    print("Yakarsa Dünyayı Garipler Yakar")

print("Program Çalışmaya Devam Ediyor")
# Out:
# 0.5
# Yakarsa Dünyayı Garipler Yakar
# Program Çalışmaya Devam Ediyor

# %% [markdown]
# ## raise

# %%
try:
    a = int(input("1. Sayıyı Giriniz:"))
    if a == 0:
        raise Exception("Sebebi neydi ki")
    b = int(input("2. Sayıyı Giriniz:"))
    print(a/b)
except ValueError:
    print("Değer Hatası")
except ZeroDivisionError as hata:
    print("Sıfıra Bölme Hatası=>",hata)
except Exception as hata:
    print("Genel Hata:=>",hata)
finally:
    print("Yakarsa Dünyayı Garipler Yakar")

print("Program Çalışmaya Devam Ediyor")
# Out:
# Değer Hatası
# Yakarsa Dünyayı Garipler Yakar
# Program Çalışmaya Devam Ediyor

# %%
def fonk(a,b):
    if a == 0 or b == 0:
        raise ZeroDivisionError("Sıfıra Bölme Hatası")
    else:
        return a/b
try:
    a = int(input("1. Sayıyı Giriniz:"))
    b = int(input("2. Sayıyı Giriniz:"))
    print(fonk(a,b))
except ValueError:
    print("Değer Hatası")
except ZeroDivisionError as hata:
    print("Sıfıra Bölme Hatası=>",hata)
except Exception as hata:
    print("Genel Hata:=>",hata)
finally:
    print("Yakarsa Dünyayı Garipler Yakar")
# Out:
# Değer Hatası
# Yakarsa Dünyayı Garipler Yakar

# %%
def fonk(a,b):
    if a == 0 or b == 0:
        raise ZeroDivisionError("Sıfıra Bölme Hatası")
    else:
        return a/b
try:
    adim = "EH41A"
    a = int(input("1. Sayıyı Giriniz:"))
    adim = "EH41B"
    b = int(input("2. Sayıyı Giriniz:"))
    adim = "EH41C"
    print(fonk(a,b))
    adim = "EH41D"
except ValueError:
    print("Değer Hatası",adim)
except ZeroDivisionError as hata:
    print("Sıfıra Bölme Hatası=>",hata,adim)
except Exception as hata:
    print("Genel Hata:=>",hata,adim)
finally:
    print("Yakarsa Dünyayı Garipler Yakar")
