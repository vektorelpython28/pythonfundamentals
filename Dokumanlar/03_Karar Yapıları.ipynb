# %%
a = 2
if a == 2:
    print("Doğru")
    print("Merhaba")
else:
    print("Yanlış")
# Out:
# Doğru
# Merhaba

# %%
a = 0
b = ""
c = []
if a:
    print("Dolu")
else:
    print("Boş")
# Out:
# Boş

# %%
giris1 = input("T.C. Kimlik Numaranızı Giriniz:")
if giris1:
    if giris1.isdigit():
        print("TC Kimlik Numarası")
    else:
        print("Sayısal Değer")
else:
    print("Giriş Hatası")
# Out:
# T.C. Kimlik Numaranızı Giriniz:
# Sayısal Değer

# %%
var1 = "a"
var2 = "A"
var1>var2
# Out:
# True

# %%
var1 = "Ş"
var2 = "A"
var1>var2
# Out:
# True

# %%
a =2 
if a % 2 == 0:print("Çift")
else:print("Tek")
# Out:
# Çift

# %% [markdown]
# https://www.w3resource.com/python-exercises/

# %%
sonuc = "Çift" if a % 2 == 0 else "Tek"

# %%
metin = "Jamiryo"
from collections import Counter
dict(Counter(metin))
# Out:
# {'J': 1, 'a': 1, 'm': 1, 'i': 1, 'r': 1, 'y': 1, 'o': 1}
